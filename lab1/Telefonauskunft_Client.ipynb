# %% [markdown]
# > Für die Abgabe:
# 1. `pipenv run jupyter notebook`
# 2. dann den server in dem python kernel starten, sonst IP + PORT schon belegt!
# 3. client im normalen standart kernel starten

# %% [markdown]
# # Transport Layer - Client

# %%
import logging
import clientserver
class Transport:
    def __init__(self):
        self._logger = logging.getLogger("vs2lab.lab1.Telefonauskunft_Client.Transport")
        
        self._logger.info("Client Transport initialized.")
    def send(self, message:str):
        socket = clientserver.Client()
        self._logger.info("Client Transport initialized.")
        socket.call(message)

# %% [markdown]
# # Auskunft Layer - Client

# %%
import logging


class Phonebook:
    
    def __init__(self):
        self._logger = logging.getLogger("vs2lab.lab1.Telefonauskunft_Client.Auskunft")
        self.transport = Transport()
        
    def GETALL(self):
        self._logger.info("Requesting all entries from phone book.")
        self.transport.send("GETALL::")

    def GET(self,name:str):
        self._logger.info(f"Requesting entry for {name} from phone book.")
        self.transport.send(f"GET::{name}")

# %% [markdown]
# # Beispiel Nutzung - Client

# %%
phonebook = Phonebook()
print(phonebook.GET("Scooby Doo"))
print(phonebook.GETALL())
# Out:
# 2025-10-08 09:30:10,700 - vs2lab.lab1.Telefonauskunft_Client.Transport - INFO - Client Transport initialized.
# 2025-10-08 09:30:10,701 - vs2lab.lab1.Telefonauskunft_Client.Auskunft - INFO - Requesting entry for Scooby Doo from phone book.
# 2025-10-08 09:30:10,702 - vs2lab.a1_layers.clientserver.Client - INFO - Client connected to socket <socket.socket fd=59, family=2, type=1, proto=0, laddr=('127.0.0.1', 43236), raddr=('127.0.0.1', 50007)>
# 2025-10-08 09:30:10,703 - vs2lab.lab1.Telefonauskunft_Client.Transport - INFO - Client Transport initialized.
# 2025-10-08 09:30:10,704 - vs2lab.a1_layers.clientserver.Client - INFO - Client down.
# 2025-10-08 09:30:10,705 - vs2lab.lab1.Telefonauskunft_Client.Auskunft - INFO - Requesting all entries from phone book.
# 2025-10-08 09:30:10,706 - vs2lab.a1_layers.clientserver.Client - INFO - Client connected to socket <socket.socket fd=58, family=2, type=1, proto=0, laddr=('127.0.0.1', 43242), raddr=('127.0.0.1', 50007)>
# 2025-10-08 09:30:10,706 - vs2lab.lab1.Telefonauskunft_Client.Transport - INFO - Client Transport initialized.
# 2025-10-08 09:30:10,707 - vs2lab.a1_layers.clientserver.Client - INFO - Client down.
# {'Scooby Doo': '555-1234'}
# None
# {'Scooby Doo': '555-1234', 'Shaggy': '555-5678'}
# None

# %% [markdown]
# # Unit Tests - Client

# %%
import unittest
from unittest.mock import patch, MagicMock

class TestPhonebook(unittest.TestCase):
    def setUp(self):
        # create a Phonebook instance but patch its transport to avoid real sockets
        self.pb = Phonebook()
        self.pb.transport = MagicMock()

    def test_get_calls_transport_with_name(self):
        self.pb.GET('Scooby Doo')
        # ensure transport.send was called with the expected message format
        self.pb.transport.send.assert_called_with('GET::Scooby Doo')

    def test_getall_calls_transport(self):
        self.pb.GETALL()
        self.pb.transport.send.assert_called_with('GETALL::')

if __name__ == '__main__':
    unittest.main(argv=['first-arg-is-ignored'], exit=False)
# Out:
# 2025-10-08 09:30:10,772 - vs2lab.lab1.Telefonauskunft_Client.Transport - INFO - Client Transport initialized.
# 2025-10-08 09:30:10,773 - vs2lab.lab1.Telefonauskunft_Client.Auskunft - INFO - Requesting entry for Scooby Doo from phone book.
# .2025-10-08 09:30:10,775 - vs2lab.lab1.Telefonauskunft_Client.Transport - INFO - Client Transport initialized.
# 2025-10-08 09:30:10,777 - vs2lab.lab1.Telefonauskunft_Client.Auskunft - INFO - Requesting all entries from phone book.
# .
# ----------------------------------------------------------------------
# Ran 2 tests in 0.008s
#
# OK
